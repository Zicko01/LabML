# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib

import sheet2
importlib.reload(sheet2)

from sheet2 import kmeans, em_gmm, plot_gmm_solution, agglo_dendro, kmeans_agglo

# %%
X = np.load("problem_set2/data/5_gaussians.npy").T

print(X.shape)
print(X[:5])
# Out:
# (500, 2)
# [[-1.4148926   1.1323373 ]
#  [-1.9174044   0.56839676]
#  [-1.6584173   1.0403728 ]
#  [-1.4835649   1.1053363 ]
#  [-1.3483359   0.89660031]]

# %%
plt.scatter(X[:,0], X[:,1], s=10, alpha=0.6)
plt.axis("equal")
plt.title("Original dataset")
plt.xlabel("x1")
plt.ylabel("x2")
plt.axis("equal")
plt.show()

# %%
# k = 5
# mu, r, loss = kmeans(X, k)

# plt.figure()

# for j in range(k):
#     mask = (r == j)
#     plt.scatter(
#         X[mask, 0],
#         X[mask, 1],
#         s=10,
#         alpha=0.6,
#         label=f"Cluster {j}"
#     )

# plt.scatter(
#     mu[:,0],
#     mu[:,1],
#     c='red',
#     marker='x',
#     s=100,
#     label='Centroids'
# )

# plt.legend()
# # plt.title(f"K-means, k={k}, loss={loss:.2f}")
# plt.axis("equal")
# plt.show()

# %%
for k in range(5, 6):
    pi, mu, sigma, loglik = em_gmm(X, k, init_kmeans=True)
    plot_gmm_solution(X, mu, sigma)
# Out:
# Iteration 1, number of changes: 10, loss: 309.92549609281076
# Iteration 2, number of changes: 10, loss: 172.95607570310193
# Iteration 3, number of changes: 10, loss: 97.87100714542898
# Iteration 4, number of changes: 8, loss: 89.9317992864961
# Iteration 5, number of changes: 4, loss: 89.35564399954755
# Iteration 6, number of changes: 4, loss: 88.86418736067458
# Iteration 7, number of changes: 4, loss: 88.70751050254117
# Iteration 8, number of changes: 4, loss: 88.68195229872411
# Iteration 9, number of changes: 4, loss: 88.61652819142327
# Iteration 10, number of changes: 4, loss: 88.603936675866
# Iteration 11, number of changes: 4, loss: 88.55107286392811
# Iteration 12, number of changes: 4, loss: 88.46561513626463
# Iteration 13, number of changes: 4, loss: 88.24498928550511
# Iteration 14, number of changes: 4, loss: 87.80086243278886
# Iteration 15, number of changes: 4, loss: 87.41895409897519
# Iteration 16, number of changes: 4, loss: 87.02131609926157
# Iteration 17, number of changes: 4, loss: 86.52705099941477
# Iteration 18, number of changes: 4, loss: 86.38480882282448
# Iteration 19, number of changes: 4, loss: 86.33884190561618
# Iteration 20, number of changes: 4, loss: 86.26871369422689
# Iteration 21, number of changes: 4, loss: 86.08011985929656
# Iteration 22, number of changes: 4, loss: 85.75886209249472
# Iteration 23, number of changes: 4, loss: 85.61080056844685
# Iteration 24, number of changes: 4, loss: 85.59200701884748
# Iteration 25, number of changes: 4, loss: 85.58635944317263
# Iteration 26, number of changes: 0, loss: 85.58635944317263
# Iteration 1, log-likelihood: -1536.449402
# Iteration 2, log-likelihood: -1215.583862
# Iteration 3, log-likelihood: -1016.640052
# Iteration 4, log-likelihood: -960.036089
# Iteration 5, log-likelihood: -948.848507
# Iteration 6, log-likelihood: -938.642130
# Iteration 7, log-likelihood: -925.434399
# Iteration 8, log-likelihood: -900.808847
# Iteration 9, log-likelihood: -839.246415
# Iteration 10, log-likelihood: -758.168600
# Iteration 11, log-likelihood: -755.998904
# Iteration 12, log-likelihood: -755.862265
# Iteration 13, log-likelihood: -755.754528
# Iteration 14, log-likelihood: -755.659297
# Iteration 15, log-likelihood: -755.567767
# Iteration 16, log-likelihood: -755.474325
# Iteration 17, log-likelihood: -755.374269
# Iteration 18, log-likelihood: -755.262617
# Iteration 19, log-likelihood: -755.133417
# Iteration 20, log-likelihood: -754.979362
# Iteration 21, log-likelihood: -754.791961
# Iteration 22, log-likelihood: -754.563237
# Iteration 23, log-likelihood: -754.290697
# Iteration 24, log-likelihood: -753.985926
# Iteration 25, log-likelihood: -753.679556
# Iteration 26, log-likelihood: -753.408708
# Iteration 27, log-likelihood: -753.193002
# Iteration 28, log-likelihood: -753.028402
# Iteration 29, log-likelihood: -752.900879
# Iteration 30, log-likelihood: -752.798021
# Iteration 31, log-likelihood: -752.711774
# Iteration 32, log-likelihood: -752.637359
# Iteration 33, log-likelihood: -752.571925
# Iteration 34, log-likelihood: -752.513669
# Iteration 35, log-likelihood: -752.461332
# Iteration 36, log-likelihood: -752.413906
# Iteration 37, log-likelihood: -752.370477
# Iteration 38, log-likelihood: -752.330199
# Iteration 39, log-likelihood: -752.292311
# Iteration 40, log-likelihood: -752.256192
# Iteration 41, log-likelihood: -752.221393
# Iteration 42, log-likelihood: -752.187636
# Iteration 43, log-likelihood: -752.154786
# Iteration 44, log-likelihood: -752.122788
# Iteration 45, log-likelihood: -752.091595
# Iteration 46, log-likelihood: -752.061090
# Iteration 47, log-likelihood: -752.030989
# Iteration 48, log-likelihood: -752.000752
# Iteration 49, log-likelihood: -751.969447
# Iteration 50, log-likelihood: -751.935535
# Iteration 51, log-likelihood: -751.896492
# Iteration 52, log-likelihood: -751.848150
# Iteration 53, log-likelihood: -751.783821
# Iteration 54, log-likelihood: -751.694391
# Iteration 55, log-likelihood: -751.574299
# Iteration 56, log-likelihood: -751.438834
# Iteration 57, log-likelihood: -751.328518
# Iteration 58, log-likelihood: -751.266324
# Iteration 59, log-likelihood: -751.238937
# Iteration 60, log-likelihood: -751.227775
# Iteration 61, log-likelihood: -751.223105
# Iteration 62, log-likelihood: -751.221036
# Iteration 63, log-likelihood: -751.220069
# Iteration 64, log-likelihood: -751.219599
# Iteration 65, log-likelihood: -751.219363
# Iteration 66, log-likelihood: -751.219243
# Iteration 67, log-likelihood: -751.219180
# Iteration 68, log-likelihood: -751.219147
# Iteration 69, log-likelihood: -751.219130
# Iteration 70, log-likelihood: -751.219120
# Convergence reached.

# %%
for k in range(5, 6):
    pi, mu, sigma, loglik = em_gmm(X, k, init_kmeans=False)
    plot_gmm_solution(X, mu, sigma)
# Out:
# Iteration 1, log-likelihood: -1549.632428
# Iteration 2, log-likelihood: -1205.600635
# Iteration 3, log-likelihood: -1024.564035
# Iteration 4, log-likelihood: -959.616289
# Iteration 5, log-likelihood: -949.942664
# Iteration 6, log-likelihood: -944.922333
# Iteration 7, log-likelihood: -937.690780
# Iteration 8, log-likelihood: -924.148834
# Iteration 9, log-likelihood: -900.705794
# Iteration 10, log-likelihood: -871.940113
# Iteration 11, log-likelihood: -841.948937
# Iteration 12, log-likelihood: -804.135383
# Iteration 13, log-likelihood: -767.656051
# Iteration 14, log-likelihood: -759.322481
# Iteration 15, log-likelihood: -757.701028
# Iteration 16, log-likelihood: -757.526504
# Iteration 17, log-likelihood: -757.388180
# Iteration 18, log-likelihood: -757.273711
# Iteration 19, log-likelihood: -757.181575
# Iteration 20, log-likelihood: -757.108334
# Iteration 21, log-likelihood: -757.049722
# Iteration 22, log-likelihood: -757.001843
# Iteration 23, log-likelihood: -756.961720
# Iteration 24, log-likelihood: -756.927301
# Iteration 25, log-likelihood: -756.897236
# Iteration 26, log-likelihood: -756.870633
# Iteration 27, log-likelihood: -756.846886
# Iteration 28, log-likelihood: -756.825558
# Iteration 29, log-likelihood: -756.806317
# Iteration 30, log-likelihood: -756.788896
# Iteration 31, log-likelihood: -756.773077
# Iteration 32, log-likelihood: -756.758672
# Iteration 33, log-likelihood: -756.745520
# Iteration 34, log-likelihood: -756.733480
# Iteration 35, log-likelihood: -756.722430
# Iteration 36, log-likelihood: -756.712261
# Iteration 37, log-likelihood: -756.702878
# Iteration 38, log-likelihood: -756.694195
# Iteration 39, log-likelihood: -756.686137
# Iteration 40, log-likelihood: -756.678636
# Iteration 41, log-likelihood: -756.671634
# Iteration 42, log-likelihood: -756.665077
# Iteration 43, log-likelihood: -756.658916
# Iteration 44, log-likelihood: -756.653109
# Iteration 45, log-likelihood: -756.647617
# Iteration 46, log-likelihood: -756.642406
# Iteration 47, log-likelihood: -756.637443
# Iteration 48, log-likelihood: -756.632699
# Iteration 49, log-likelihood: -756.628148
# Iteration 50, log-likelihood: -756.623766
# Iteration 51, log-likelihood: -756.619530
# Iteration 52, log-likelihood: -756.615419
# Iteration 53, log-likelihood: -756.611413
# Iteration 54, log-likelihood: -756.607493
# Iteration 55, log-likelihood: -756.603641
# Iteration 56, log-likelihood: -756.599839
# Iteration 57, log-likelihood: -756.596071
# Iteration 58, log-likelihood: -756.592319
# Iteration 59, log-likelihood: -756.588567
# Iteration 60, log-likelihood: -756.584798
# Iteration 61, log-likelihood: -756.580994
# Iteration 62, log-likelihood: -756.577136
# Iteration 63, log-likelihood: -756.573207
# Iteration 64, log-likelihood: -756.569187
# Iteration 65, log-likelihood: -756.565053
# Iteration 66, log-likelihood: -756.560785
# Iteration 67, log-likelihood: -756.556357
# Iteration 68, log-likelihood: -756.551743
# Iteration 69, log-likelihood: -756.546915
# Iteration 70, log-likelihood: -756.541842
# Iteration 71, log-likelihood: -756.536491
# Iteration 72, log-likelihood: -756.530823
# Iteration 73, log-likelihood: -756.524799
# Iteration 74, log-likelihood: -756.518374
# Iteration 75, log-likelihood: -756.511502
# Iteration 76, log-likelihood: -756.504130
# Iteration 77, log-likelihood: -756.496203
# Iteration 78, log-likelihood: -756.487664
# Iteration 79, log-likelihood: -756.478450
# Iteration 80, log-likelihood: -756.468499
# Iteration 81, log-likelihood: -756.457747
# Iteration 82, log-likelihood: -756.446132
# Iteration 83, log-likelihood: -756.433598
# Iteration 84, log-likelihood: -756.420092
# Iteration 85, log-likelihood: -756.405578
# Iteration 86, log-likelihood: -756.390029
# Iteration 87, log-likelihood: -756.373443
# Iteration 88, log-likelihood: -756.355839
# Iteration 89, log-likelihood: -756.337266
# Iteration 90, log-likelihood: -756.317801
# Iteration 91, log-likelihood: -756.297553
# Iteration 92, log-likelihood: -756.276660
# Iteration 93, log-likelihood: -756.255282
# Iteration 94, log-likelihood: -756.233599
# Iteration 95, log-likelihood: -756.211797
# Iteration 96, log-likelihood: -756.190059
# Iteration 97, log-likelihood: -756.168557
# Iteration 98, log-likelihood: -756.147442
# Iteration 99, log-likelihood: -756.126836
# Iteration 100, log-likelihood: -756.106833

# %%
k = 8
mu, r, loss = kmeans(X, k)

plt.figure()

for j in range(k):
    mask = (r == j)
    plt.scatter(
        X[mask, 0],
        X[mask, 1],
        s=10,
        alpha=0.6,
        label=f"Cluster {j}"
    )

plt.scatter(
    mu[:,0],
    mu[:,1],
    c='red',
    marker='x',
    s=100,
    label='Centroids'
)

plt.legend()
# plt.title(f"K-means, k={k}, loss={loss:.2f}")
plt.axis("equal")
plt.show()
# Out:
# Iteration 1, number of changes: 16, loss: 85.4969145120917
# Iteration 2, number of changes: 16, loss: 46.75337884053292
# Iteration 3, number of changes: 12, loss: 45.08184329504769
# Iteration 4, number of changes: 10, loss: 44.894024765504454
# Iteration 5, number of changes: 6, loss: 44.81966144549588
# Iteration 6, number of changes: 6, loss: 44.75629801841698
# Iteration 7, number of changes: 6, loss: 44.68510206403334
# Iteration 8, number of changes: 6, loss: 44.60296891983701
# Iteration 9, number of changes: 6, loss: 44.55624690625763
# Iteration 10, number of changes: 4, loss: 44.52504708465585
# Iteration 11, number of changes: 0, loss: 44.52504708465585

# %%
R, kmloss, mergeidx = kmeans_agglo(X, r)

# %%
agglo_dendro(kmloss, mergeidx)
